# %% [markdown]
# 1. Task
#
# - Generate the following simple statistics:
#
# 1.1 Report the total number of crimes in the dataset.
# 1.2 List the various categories of crime. How many are there?
# 1.3 List the number of crimes in each category.

# %%
import pandas as pd
#Læs Pandas libraries/biblioteker som pd

df = pd.read_csv('sf_crime_data.csv')
#Læs csv filen crime data som 2-dimensionel datastruktur: Dataframe. Tabel med kolonner og rækker

# %%
df.head(35)
#Vis en overblik over de 5 første datasæt fra toppen i filen

#Tabellen viser PdId som er "IncidentNum + 0 + Incident code"
#Pd står muligvis for "Police Department"
#Blandt andre informationer
# Out:
#               PdId  IncidntNum  Incident Code        Category  \
# 0    4133422003074    41334220           3074         ROBBERY
# 1    5118535807021    51185358           7021   VEHICLE THEFT
# 2    4018830907021    40188309           7021   VEHICLE THEFT
# 3   11014543126030   110145431          26030           ARSON
# 4   10108108004134   101081080           4134         ASSAULT
# 5   13027069804134   130270698           4134         ASSAULT
# 6   17063991304134   170639913           4134         ASSAULT
# 7   16020415607020   160204156           7020   VEHICLE THEFT
# 8    6068579904134    60685799           4134         ASSAULT
# 9    5134166327195    51341663          27195        TRESPASS
# 10   9098843805041    90988438           5041        BURGLARY
# 11  12620267506244   126202675           6244   LARCENY/THEFT
# 12   4113838962020    41138389          62020        WARRANTS
# 13  10014538865016   100145388          65016  OTHER OFFENSES
# ...

# %%
# 1.1 Total amount of crimes in SF
